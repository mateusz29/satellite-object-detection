# %%
from rfdetr import RFDETRLarge
from rfdetr_plus import RFDETR2XLarge, RFDETRXLarge
# Out:
# d:\studia\magisterka\satellite-object-detection\.venv\Lib\site-packages\rfdetr\models\weights.py:258: FutureWarning: target=True is deprecated since `v0.8`; use `TargetMode.ARGS_REMAP` instead. Will be removed in `v1.0`.
#   @deprecated(target=True, args_mapping={"train_config": None}, deprecated_in="1.7.0", remove_in="1.9.0", num_warns=-1)

# %%
model = RFDETRLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models//rf_detr_large.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_large")
# Out:
# [2026-07-11 18:55:21] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:55:21] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:55:28] [WARNING] rf-detr - Checkpoint has 5 classes but model is configured for 90. Using checkpoint class count (5). Pass num_classes=5 to suppress this warning.
# [2026-07-11 18:55:30] [WARNING] rf-detr - Checkpoint has 5 classes but model is configured for 90. Using checkpoint class count (5). Pass num_classes=5 to suppress this warning.
# ...

# %%
model = RFDETRXLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models//rf_detr_xlarge.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_xlarge")
# Out:
# [2026-07-11 18:56:28] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:56:28] [WARNING] rf-detr - Using patch size 20 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:56:35] [WARNING] rf-detr - Checkpoint has 90 classes but model is configured for 365. Using checkpoint class count (90). Pass num_classes=90 to suppress this warning.
# [2026-07-11 18:56:35] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# ...

# %%
model = RFDETR2XLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models//rf_detr_2xlarge.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_2xlarge")
# Out:
# [2026-07-11 18:57:00] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:57:00] [WARNING] rf-detr - Using patch size 20 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-07-11 18:57:08] [WARNING] rf-detr - Checkpoint has 90 classes but model is configured for 365. Using checkpoint class count (90). Pass num_classes=90 to suppress this warning.
# [2026-07-11 18:57:08] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# ...

# %%
model = RFDETRLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models2//rfdetr_large//checkpoint_best_total.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_large")
# Out:
# [2026-08-07 14:20:09] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:20:09] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:20:12] [WARNING] rf-detr - Checkpoint has 6 classes but model is configured for 90. Using checkpoint class count (6). Pass num_classes=6 to suppress this warning.
# [2026-08-07 14:20:12] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# [2026-08-07 14:20:12] [INFO] rf-detr - Exporting model to ONNX format
# ...

# %%
model = RFDETRXLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models2//rfdetr_extralarge//checkpoint_best_total.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_xlarge")
# Out:
# [2026-08-07 14:20:33] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:20:33] [WARNING] rf-detr - Using patch size 20 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:20:40] [WARNING] rf-detr - Checkpoint has 90 classes but model is configured for 365. Using checkpoint class count (90). Pass num_classes=90 to suppress this warning.
# [2026-08-07 14:20:40] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# [2026-08-07 14:20:40] [INFO] rf-detr - Exporting model to ONNX format
# [2026-08-07 14:20:50] [INFO] rf-detr -
# Successfully exported ONNX model: C:\Users\mati\Downloads\rf_detr_xlarge\rfdetr-xlarge.onnx
# ...

# %%
model = RFDETR2XLarge(
    pretrain_weights="D://studia//magisterka//satellite-object-detection//trained_models2//rfdetr_2extralarge//checkpoint_best_total.pth"
)

model.export(output_dir="C://Users//mati//Downloads//rf_detr_2xlarge")
# Out:
# [2026-08-07 14:20:50] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:20:50] [WARNING] rf-detr - Using patch size 20 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-08-07 14:21:00] [WARNING] rf-detr - Checkpoint has 90 classes but model is configured for 365. Using checkpoint class count (90). Pass num_classes=90 to suppress this warning.
# [2026-08-07 14:21:00] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# [2026-08-07 14:21:00] [INFO] rf-detr - Exporting model to ONNX format
# [2026-08-07 14:21:11] [INFO] rf-detr -
# Successfully exported ONNX model: C:\Users\mati\Downloads\rf_detr_2xlarge\rfdetr-2xlarge.onnx
# ...
